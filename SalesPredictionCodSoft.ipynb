# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
from sklearn.linear_model import LinearRegression

# %%
df = pd.read_csv("advertising.csv")
df.head()
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3   12.0
# 3  151.5   41.3       58.5   16.5
# 4  180.8   10.8       58.4   17.9

# %%
df.corr()
# Out:
#                  TV     Radio  Newspaper     Sales
# TV         1.000000  0.054809   0.056648  0.901208
# Radio      0.054809  1.000000   0.354104  0.349631
# Newspaper  0.056648  0.354104   1.000000  0.157960
# Sales      0.901208  0.349631   0.157960  1.000000

# %%
sns.heatmap(df.corr())
# Out:
# <Axes: >

# %%
sns.set_theme(
    context = 'paper',
    style = 'darkgrid'
)
sns.regplot(color = 'red', data = df, x = 'TV', y = 'Sales')
# Out:
# <Axes: xlabel='TV', ylabel='Sales'>

# %%
X = df.iloc[:, :3]
Y = df.iloc[:, 3]

x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size = 0.3, random_state = 90)

# %%
regressor = LinearRegression()
regressor.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = regressor.predict(x_test)
y_pred
# Out:
# array([18.11653409, 20.13683991, 10.86938818, 12.91065166, 20.86438239,
#         9.07913925, 12.82961578, 10.17147304, 11.99676617, 11.84134257,
#        17.7625425 , 12.7409891 , 11.92380535, 13.34866827, 17.41211272,
#        15.49961977, 12.23739965,  9.70023371, 10.97742516, 20.49615253,
#        11.11839488, 21.55556573, 18.39796099, 20.60314973, 15.40646891,
#        14.72888558, 21.29050989, 17.13896503, 16.54166026, 20.4788703 ,
#        12.20053152,  7.24622992, 10.92698406, 16.07917278,  8.89160667,
#        21.16754243, 16.80951682, 18.4017431 , 16.02952622, 14.17555032,
#        19.03308171, 14.90811128, 16.23487095, 21.02242051, 12.67390387,
#        17.97708805, 17.42654519, 13.3397065 , 19.66529974, 22.93261081,
#        19.97907288, 18.89359241,  6.95975232, 20.12875564, 21.45264301,
#         9.55844825, 15.83512628, 24.84232844,  8.65628436,  7.80039337])

# %%
accuracy = r2_score(y_test, y_pred)*100
print("Accuracy: {}%".format(accuracy))
# Out:
# Accuracy: 89.0873480953664%
